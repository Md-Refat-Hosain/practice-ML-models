# %%
# Import Libreries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
import statistics as st


from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import confusion_matrix
# %matplotlib inline

# %%
# Reading data

# %%
df = pd.read_csv('/content/drive/MyDrive/ud ds+ml (logistic regress....)/01Exercise1.csv')

# %%
df
# Out:
#      gender married   ch  income  loanamt status
# 0      Male      No  1.0    5849      NaN      Y
# 1      Male     Yes  1.0    4583    128.0      N
# 2      Male     Yes  1.0    3000     66.0      Y
# 3      Male     Yes  1.0    2583    120.0      Y
# 4      Male      No  1.0    6000    141.0      Y
# ..      ...     ...  ...     ...      ...    ...
# 609  Female      No  1.0    2900     71.0      Y
# 610    Male     Yes  1.0    4106     40.0      Y
# 611    Male     Yes  1.0    8072    253.0      Y
# 612    Male     Yes  1.0    7583    187.0      Y
# 613  Female      No  0.0    4583    133.0      N
#
# [614 rows x 6 columns]

# %%
LoanData = df.copy()

# %%
# Identify the missing values and drop them

# %%
LoanData.isna().sum()
# Out:
# gender     13
# married     3
# ch         50
# income      0
# loanamt    22
# status      0
# dtype: int64

# %%
LoanData = LoanData.dropna()

# %%
LoanData
# Out:
#      gender married   ch  income  loanamt status
# 1      Male     Yes  1.0    4583    128.0      N
# 2      Male     Yes  1.0    3000     66.0      Y
# 3      Male     Yes  1.0    2583    120.0      Y
# 4      Male      No  1.0    6000    141.0      Y
# 5      Male     Yes  1.0    5417    267.0      Y
# ..      ...     ...  ...     ...      ...    ...
# 609  Female      No  1.0    2900     71.0      Y
# 610    Male     Yes  1.0    4106     40.0      Y
# 611    Male     Yes  1.0    8072    253.0      Y
# 612    Male     Yes  1.0    7583    187.0      Y
# 613  Female      No  0.0    4583    133.0      N
#
# [529 rows x 6 columns]

# %%
# Drop the irrelevent columns and genders

# %%
LoanData = LoanData.drop(['gender'] , axis = 1)

# %%
# Create Dummie variables

# %%
LoanData = pd.get_dummies(LoanData , drop_first= True)

# %%
LoanData
# Out:
#       ch  income  loanamt  married_Yes  status_Y
# 1    1.0    4583    128.0         True     False
# 2    1.0    3000     66.0         True      True
# 3    1.0    2583    120.0         True      True
# 4    1.0    6000    141.0        False      True
# 5    1.0    5417    267.0         True      True
# ..   ...     ...      ...          ...       ...
# 609  1.0    2900     71.0        False      True
# 610  1.0    4106     40.0         True      True
# 611  1.0    8072    253.0         True      True
# 612  1.0    7583    187.0         True      True
# 613  0.0    4583    133.0        False     False
#
# [529 rows x 5 columns]

# %%
# Changing boolean to int

# %%
LoanData[['married_Yes','status_Y']] = LoanData[['married_Yes' , 'status_Y']].astype(int)

# %%
LoanData
# Out:
#       ch  income  loanamt  married_Yes  status_Y
# 1    1.0    4583    128.0            1         0
# 2    1.0    3000     66.0            1         1
# 3    1.0    2583    120.0            1         1
# 4    1.0    6000    141.0            0         1
# 5    1.0    5417    267.0            1         1
# ..   ...     ...      ...          ...       ...
# 609  1.0    2900     71.0            0         1
# 610  1.0    4106     40.0            1         1
# 611  1.0    8072    253.0            1         1
# 612  1.0    7583    187.0            1         1
# 613  0.0    4583    133.0            0         0
#
# [529 rows x 5 columns]

# %%
# Normalize the data for Loan amount and income

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler_ = StandardScaler()

# %%
LoanData['income'] = scaler_.fit_transform(LoanData[['income']])
LoanData['loanamt'] = scaler_.fit_transform(LoanData[['loanamt']])

# %%
LoanData
# Out:
#       ch    income   loanamt  married_Yes  status_Y
# 1    1.0 -0.128073 -0.194250            1         0
# 2    1.0 -0.392077 -0.971015            1         1
# 3    1.0 -0.461621 -0.294478            1         1
# 4    1.0  0.108246 -0.031380            0         1
# 5    1.0  0.011017  1.547205            1         1
# ..   ...       ...       ...          ...       ...
# 609  1.0 -0.408754 -0.908372            0         1
# 610  1.0 -0.207624 -1.296754            1         1
# 611  1.0  0.453802  1.371807            1         1
# 612  1.0  0.372249  0.544929            1         1
# 613  0.0 -0.128073 -0.131608            0         0
#
# [529 rows x 5 columns]

# %%
# dividing the data into X and y

# %%
X = LoanData.drop('status_Y' , axis = 1)
y = LoanData['status_Y']

# %%
# spliting  X and y to train the model

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size=.3 , random_state=42 , stratify=y)

# %%
# Build the Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train , y_train)
# Out:
# LogisticRegression()

# %%
y_preds = lr.predict(X_test)

# %%
# Import confusion matrics

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test , y_preds)
cm
# Out:
# array([[ 25,  24],
#        [  0, 110]])

# %%
# Score them

# %%
score = lr.score(X_test , y_test)

# %%
score
# Out:
# 0.8490566037735849
